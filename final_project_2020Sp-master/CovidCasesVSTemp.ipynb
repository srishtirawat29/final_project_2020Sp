# %% [markdown]
# ## Hypothesis: Warmer regions have lesser number of COVID-19 cases

# %% [markdown]
# ### New Cases per capita worldwide

# %%
import pandas as pd
import numpy as np

# %%
new_cases_percapita = pd.read_csv('new_cases_per_million.csv')
new_cases_percapita
# Out:
#            date   World  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 0    2019-12-31   0.003        0.000      NaN    0.000      NaN     NaN
# 1    2020-01-01   0.000        0.000      NaN    0.000      NaN     NaN
# 2    2020-01-02   0.000        0.000      NaN    0.000      NaN     NaN
# 3    2020-01-03   0.002        0.000      NaN    0.000      NaN     NaN
# 4    2020-01-04   0.000        0.000      NaN    0.000      NaN     NaN
# ..          ...     ...          ...      ...      ...      ...     ...
# 117  2020-04-26  13.049        2.877   11.815    2.942   25.885    0.00
# 118  2020-04-27  10.717        1.747    4.865    2.873   90.597    0.03
# 119  2020-04-28   8.394        4.418    3.475    3.079   38.827    0.03
# 120  2020-04-29   9.363        3.185    4.865    3.010   64.712    0.00
# 121  2020-04-30   9.800        3.134    5.560    4.538   64.712    0.00
#
#      Anguilla  Antigua and Barbuda  Argentina  ...  \
# ...
